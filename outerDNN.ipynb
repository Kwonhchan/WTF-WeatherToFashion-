# %%
import os
import json
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import glob
from tensorflow.keras.layers import BatchNormalization

# %%
# 데이터 로드 및 전처리 함수
def load_and_preprocess_data(json_file_path):
    with open(json_file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    gender = data['metadata.model']['metadata.model.gender']
    age = data['metadata.model']['metadata.model.age']
    season = data['metadata.clothes']['metadata.clothes.season']
    clothing_type = data['metadata.clothes']['metadata.clothes.type']
    
    return gender, age, season, clothing_type

# 데이터셋 폴더 경로
dataset_folder = 'Dataset/outer'

# 데이터셋 구축
data_list = []
# Dataset/bottom 폴더의 모든 JSON 파일을 불러와서 데이터셋을 구축합니다.
for root, _, files in os.walk(dataset_folder):
    for file in files:
        if file.endswith('.json'):
            json_file_path = os.path.join(root, file)
            gender, age, season, clothing_type = load_and_preprocess_data(json_file_path)
            data_list.append([gender, age, season, clothing_type])

# DataFrame으로 변환
df = pd.DataFrame(data_list, columns=['gender', 'age', 'season', 'clothing_type'])

# Label Encoding
label_encoders = {}

# 성별과 계절을 라벨 인코딩
for column in ['gender', 'season']:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])

# 나이를 범주형으로 변환
age_categories = ['10대', '20대', '30대', '40대', '50대', '60대']
df['age'] = pd.Categorical(df['age'], categories=age_categories, ordered=True)
df = pd.get_dummies(df, columns=['age'])

# 입력 데이터와 출력 데이터 분리
X = df.drop(columns=['clothing_type']).values.astype(float)
y_clothing_type = df['clothing_type'].values
y_season = df['season'].values

# 데이터 정규화
scaler = StandardScaler()
X = scaler.fit_transform(X)

# 출력 데이터 라벨 인코딩
clothing_type_encoder = LabelEncoder()
y_clothing_type = clothing_type_encoder.fit_transform(y_clothing_type)

# 학습 데이터와 검증 데이터로 분리
X_train, X_val, y_clothing_type_train, y_clothing_type_val = train_test_split(X, y_clothing_type, test_size=0.2, random_state=42)
_, _, y_season_train, y_season_val = train_test_split(X, y_season, test_size=0.2, random_state=42)

# %%
# DNN 모델 설계
def create_dnn_model(input_shape, output_shape_clothing_type, output_shape_season):
    inputs = Input(shape=input_shape)
    
    # 첫 번째 블록
    x = Dense(512, activation='relu')(inputs)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # 두 번째 블록
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # 세 번째 블록
    x = Dense(128, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # 네 번째 블록
    x = Dense(64, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    
    # 다섯 번째 블록
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.1)(x)
    
    # 출력 레이어
    clothing_type_output = Dense(output_shape_clothing_type, activation='softmax', name='clothing_type_output')(x)
    season_output = Dense(output_shape_season, activation='softmax', name='season_output')(x)
    
    model = Model(inputs=inputs, outputs=[clothing_type_output, season_output])
    
    model.compile(
        optimizer='adam', 
        loss={
            'clothing_type_output': 'sparse_categorical_crossentropy', 
            'season_output': 'sparse_categorical_crossentropy'
        },
        metrics={
            'clothing_type_output': 'accuracy', 
            'season_output': 'accuracy'
        }
    )
    return model


# 모델 생성
model = create_dnn_model((X_train.shape[1],), len(np.unique(y_clothing_type)), len(np.unique(y_season)))

# 모델 체크포인트 콜백 설정
checkpoint = ModelCheckpoint(
    'best_model_{epoch:02d}_{val_loss:.2f}_{val_clothing_type_output_accuracy:.2f}.keras', 
    monitor='val_clothing_type_output_accuracy', 
    save_best_only=True, 
    mode='max', 
    verbose=1
)

# 얼리 스토핑 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min', verbose=1)

# 모델 학습
model.fit(
    X_train, 
    {'clothing_type_output': y_clothing_type_train, 'season_output': y_season_train},
    epochs=100, 
    batch_size=32,
    validation_data=(X_val, {'clothing_type_output': y_clothing_type_val, 'season_output': y_season_val}), 
    callbacks=[checkpoint, early_stopping]
)

# 가장 최근에 저장된 모델 파일 찾기
latest_model = max(glob.glob('best_model_*.keras'), key=os.path.getctime)

# 저장된 모델 로드
best_model = tf.keras.models.load_model(latest_model)

# 모델 평가
losses = best_model.evaluate(X_val, {'clothing_type_output': y_clothing_type_val, 'season_output': y_season_val}, return_dict=True)
print("Evaluation losses and metrics:", losses)

# 딕셔너리 키 확인
print("Keys in evaluation dictionary:", losses.keys())

# 각 값의 인덱스를 확인한 후 올바르게 참조
clothing_type_loss = losses.get('clothing_type_output_loss', None)
season_loss = losses.get('season_output_loss', None)
clothing_type_accuracy = losses.get('clothing_type_output_accuracy', None)
season_accuracy = losses.get('season_output_accuracy', None)

print(f'Best Clothing Type Model Accuracy: {clothing_type_accuracy:.2f}')
print(f'Best Season Model Accuracy: {season_accuracy:.2f}')
# Out:
# Epoch 1/100
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.2985 - loss: 2.4672 - season_output_accuracy: 0.6706
# Epoch 1: val_clothing_type_output_accuracy improved from -inf to 0.28803, saving model to best_model_01_2.17_0.29.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - clothing_type_output_accuracy: 0.2996 - loss: 2.4289 - season_output_accuracy: 0.6845 - val_clothing_type_output_accuracy: 0.2880 - val_loss: 2.1664 - val_season_output_accuracy: 0.9757
# Epoch 2/100
# 46/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3372 - loss: 1.6364 - season_output_accuracy: 0.9521
# Epoch 2: val_clothing_type_output_accuracy did not improve from 0.28803
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3393 - loss: 1.6300 - season_output_accuracy: 0.9534 - val_clothing_type_output_accuracy: 0.2637 - val_loss: 2.2467 - val_season_output_accuracy: 0.3611
# Epoch 3/100
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3476 - loss: 1.4699 - season_output_accuracy: 0.9819
# Epoch 3: val_clothing_type_output_accuracy did not improve from 0.28803
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3476 - loss: 1.4698 - season_output_accuracy: 0.9818 - val_clothing_type_output_accuracy: 0.2779 - val_loss: 2.2624 - val_season_output_accuracy: 0.2414
# Epoch 4/100
# 53/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3612 - loss: 1.4550 - season_output_accuracy: 0.9848
# Epoch 4: val_clothing_type_output_accuracy did not improve from 0.28803
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3611 - loss: 1.4520 - season_output_accuracy: 0.9847 - val_clothing_type_output_accuracy: 0.2799 - val_loss: 2.4825 - val_season_output_accuracy: 0.2617
# Epoch 5/100
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3814 - loss: 1.3809 - season_output_accuracy: 0.9921
# Epoch 5: val_clothing_type_output_accuracy did not improve from 0.28803
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3792 - loss: 1.3822 - season_output_accuracy: 0.9920 - val_clothing_type_output_accuracy: 0.2799 - val_loss: 1.9119 - val_season_output_accuracy: 0.8864
# Epoch 6/100
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3544 - loss: 1.3929 - season_output_accuracy: 0.9940
# Epoch 6: val_clothing_type_output_accuracy improved from 0.28803 to 0.34077, saving model to best_model_06_1.43_0.34.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3560 - loss: 1.3912 - season_output_accuracy: 0.9939 - val_clothing_type_output_accuracy: 0.3408 - val_loss: 1.4303 - val_season_output_accuracy: 1.0000
# Epoch 7/100
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3781 - loss: 1.3586 - season_output_accuracy: 0.9921
# Epoch 7: val_clothing_type_output_accuracy improved from 0.34077 to 0.40974, saving model to best_model_07_1.31_0.41.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3778 - loss: 1.3579 - season_output_accuracy: 0.9922 - val_clothing_type_output_accuracy: 0.4097 - val_loss: 1.3137 - val_season_output_accuracy: 1.0000
# Epoch 8/100
# 41/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4032 - loss: 1.3208 - season_output_accuracy: 0.9943
# Epoch 8: val_clothing_type_output_accuracy improved from 0.40974 to 0.41176, saving model to best_model_08_1.26_0.41.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3935 - loss: 1.3302 - season_output_accuracy: 0.9939 - val_clothing_type_output_accuracy: 0.4118 - val_loss: 1.2640 - val_season_output_accuracy: 1.0000
# Epoch 9/100
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3619 - loss: 1.3598 - season_output_accuracy: 0.9888
# Epoch 9: val_clothing_type_output_accuracy improved from 0.41176 to 0.41379, saving model to best_model_09_1.27_0.41.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3623 - loss: 1.3594 - season_output_accuracy: 0.9888 - val_clothing_type_output_accuracy: 0.4138 - val_loss: 1.2679 - val_season_output_accuracy: 1.0000
# Epoch 10/100
# 57/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3784 - loss: 1.3169 - season_output_accuracy: 0.9967
# Epoch 10: val_clothing_type_output_accuracy improved from 0.41379 to 0.41785, saving model to best_model_10_1.27_0.42.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3785 - loss: 1.3171 - season_output_accuracy: 0.9967 - val_clothing_type_output_accuracy: 0.4178 - val_loss: 1.2708 - val_season_output_accuracy: 1.0000
# Epoch 11/100
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4022 - loss: 1.3093 - season_output_accuracy: 0.9944
# Epoch 11: val_clothing_type_output_accuracy did not improve from 0.41785
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3999 - loss: 1.3102 - season_output_accuracy: 0.9947 - val_clothing_type_output_accuracy: 0.4118 - val_loss: 1.2619 - val_season_output_accuracy: 1.0000
# Epoch 12/100
# 60/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3773 - loss: 1.3385 - season_output_accuracy: 0.9935
# Epoch 12: val_clothing_type_output_accuracy improved from 0.41785 to 0.42191, saving model to best_model_12_1.27_0.42.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3779 - loss: 1.3378 - season_output_accuracy: 0.9936 - val_clothing_type_output_accuracy: 0.4219 - val_loss: 1.2674 - val_season_output_accuracy: 1.0000
# Epoch 13/100
# 59/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3948 - loss: 1.3010 - season_output_accuracy: 0.9959
# Epoch 13: val_clothing_type_output_accuracy did not improve from 0.42191
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3946 - loss: 1.3016 - season_output_accuracy: 0.9960 - val_clothing_type_output_accuracy: 0.4118 - val_loss: 1.2641 - val_season_output_accuracy: 1.0000
# Epoch 14/100
# 54/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3612 - loss: 1.3491 - season_output_accuracy: 0.9941
# Epoch 14: val_clothing_type_output_accuracy did not improve from 0.42191
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3634 - loss: 1.3457 - season_output_accuracy: 0.9944 - val_clothing_type_output_accuracy: 0.4037 - val_loss: 1.2610 - val_season_output_accuracy: 1.0000
# Epoch 15/100
# 43/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3851 - loss: 1.3086 - season_output_accuracy: 0.9986
# Epoch 15: val_clothing_type_output_accuracy did not improve from 0.42191
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3820 - loss: 1.3143 - season_output_accuracy: 0.9968 - val_clothing_type_output_accuracy: 0.4158 - val_loss: 1.2686 - val_season_output_accuracy: 1.0000
# Epoch 16/100
# 43/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3771 - loss: 1.3133 - season_output_accuracy: 0.9885
# Epoch 16: val_clothing_type_output_accuracy did not improve from 0.42191
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3775 - loss: 1.3137 - season_output_accuracy: 0.9905 - val_clothing_type_output_accuracy: 0.4138 - val_loss: 1.2559 - val_season_output_accuracy: 1.0000
# Epoch 17/100
# 42/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.4073 - loss: 1.2958 - season_output_accuracy: 0.9977
# Epoch 17: val_clothing_type_output_accuracy improved from 0.42191 to 0.42394, saving model to best_model_17_1.25_0.42.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.4036 - loss: 1.2995 - season_output_accuracy: 0.9978 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2537 - val_season_output_accuracy: 1.0000
# Epoch 18/100
# 47/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.4104 - loss: 1.2916 - season_output_accuracy: 0.9997
# Epoch 18: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4068 - loss: 1.2921 - season_output_accuracy: 0.9995 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2546 - val_season_output_accuracy: 1.0000
# Epoch 19/100
# 43/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3592 - loss: 1.3008 - season_output_accuracy: 0.9991
# Epoch 19: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3633 - loss: 1.2993 - season_output_accuracy: 0.9990 - val_clothing_type_output_accuracy: 0.4219 - val_loss: 1.2597 - val_season_output_accuracy: 1.0000
# Epoch 20/100
# 44/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.4196 - loss: 1.2832 - season_output_accuracy: 0.9934
# Epoch 20: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4104 - loss: 1.2877 - season_output_accuracy: 0.9942 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2630 - val_season_output_accuracy: 1.0000
# Epoch 21/100
# 52/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3621 - loss: 1.3024 - season_output_accuracy: 0.9986
# Epoch 21: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3639 - loss: 1.3016 - season_output_accuracy: 0.9986 - val_clothing_type_output_accuracy: 0.4219 - val_loss: 1.2535 - val_season_output_accuracy: 1.0000
# Epoch 22/100
# 51/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4067 - loss: 1.2806 - season_output_accuracy: 0.9975
# Epoch 22: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.4038 - loss: 1.2833 - season_output_accuracy: 0.9969 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2575 - val_season_output_accuracy: 1.0000
# Epoch 23/100
# 56/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3858 - loss: 1.2820 - season_output_accuracy: 1.0000
# Epoch 23: val_clothing_type_output_accuracy did not improve from 0.42394
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3867 - loss: 1.2826 - season_output_accuracy: 0.9999 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2548 - val_season_output_accuracy: 1.0000
# Epoch 24/100
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3987 - loss: 1.2868 - season_output_accuracy: 0.9982
# Epoch 24: val_clothing_type_output_accuracy improved from 0.42394 to 0.43002, saving model to best_model_24_1.25_0.43.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3984 - loss: 1.2875 - season_output_accuracy: 0.9982 - val_clothing_type_output_accuracy: 0.4300 - val_loss: 1.2540 - val_season_output_accuracy: 1.0000
# Epoch 25/100
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3819 - loss: 1.2906 - season_output_accuracy: 0.9977
# Epoch 25: val_clothing_type_output_accuracy did not improve from 0.43002
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3814 - loss: 1.2912 - season_output_accuracy: 0.9978 - val_clothing_type_output_accuracy: 0.4138 - val_loss: 1.2560 - val_season_output_accuracy: 1.0000
# Epoch 26/100
# 44/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.4016 - loss: 1.2724 - season_output_accuracy: 0.9989
# Epoch 26: val_clothing_type_output_accuracy did not improve from 0.43002
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3978 - loss: 1.2778 - season_output_accuracy: 0.9987 - val_clothing_type_output_accuracy: 0.4178 - val_loss: 1.2531 - val_season_output_accuracy: 1.0000
# Epoch 27/100
# 58/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4004 - loss: 1.3050 - season_output_accuracy: 0.9978
# Epoch 27: val_clothing_type_output_accuracy did not improve from 0.43002
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - clothing_type_output_accuracy: 0.3997 - loss: 1.3041 - season_output_accuracy: 0.9978 - val_clothing_type_output_accuracy: 0.4239 - val_loss: 1.2537 - val_season_output_accuracy: 1.0000
# Epoch 28/100
# 45/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3766 - loss: 1.2676 - season_output_accuracy: 0.9978
# Epoch 28: val_clothing_type_output_accuracy did not improve from 0.43002
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3781 - loss: 1.2704 - season_output_accuracy: 0.9981 - val_clothing_type_output_accuracy: 0.4300 - val_loss: 1.2539 - val_season_output_accuracy: 1.0000
# Epoch 29/100
# 61/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3942 - loss: 1.2752 - season_output_accuracy: 1.0000
# Epoch 29: val_clothing_type_output_accuracy did not improve from 0.43002
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3941 - loss: 1.2753 - season_output_accuracy: 1.0000 - val_clothing_type_output_accuracy: 0.4199 - val_loss: 1.2551 - val_season_output_accuracy: 1.0000
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.4124 - loss: 1.2802 - season_output_accuracy: 0.9999
# Epoch 30: val_clothing_type_output_accuracy improved from 0.43002 to 0.43408, saving model to best_model_30_1.25_0.43.keras
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - clothing_type_output_accuracy: 0.4124 - loss: 1.2801 - season_output_accuracy: 0.9999 - val_clothing_type_output_accuracy: 0.4341 - val_loss: 1.2538 - val_season_output_accuracy: 1.0000
# Epoch 31/100
# 45/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - clothing_type_output_accuracy: 0.3947 - loss: 1.2880 - season_output_accuracy: 0.9987
# Epoch 31: val_clothing_type_output_accuracy did not improve from 0.43408
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - clothing_type_output_accuracy: 0.3945 - loss: 1.2877 - season_output_accuracy: 0.9985 - val_clothing_type_output_accuracy: 0.4320 - val_loss: 1.2579 - val_season_output_accuracy: 1.0000
# Epoch 31: early stopping
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - clothing_type_output_accuracy: 0.4206 - loss: 1.2478 - season_output_accuracy: 1.0000
# Evaluation losses and metrics: {'clothing_type_output_accuracy': 0.43407708406448364, 'loss': 1.2537775039672852, 'season_output_accuracy': 1.0}
# Keys in evaluation dictionary: dict_keys(['clothing_type_output_accuracy', 'loss', 'season_output_accuracy'])
# Best Clothing Type Model Accuracy: 0.43
# Best Season Model Accuracy: 1.00

# %%
# 계절을 온도로 매핑하는 함수
def temperature_to_season(temperature):
    if temperature >= 25:
        return 'summer'
    elif temperature <= 5:
        return 'winter'
    else:
        return 'spring&fall'

# 예측 함수
def predict(input_data):
    input_data_transformed = [label_encoders['gender'].transform([input_data['gender']])[0]]
    
    # 나이를 원-핫 인코딩
    age_dummies = pd.get_dummies(pd.Categorical([input_data['age']], categories=age_categories))
    age_values = age_dummies.iloc[0].values
    
    season = temperature_to_season(input_data['temperature'])
    season_transformed = label_encoders['season'].transform([season])[0]
    
    input_data_array = np.concatenate([input_data_transformed, age_values, [season_transformed]]).reshape(1, -1)
    input_data_array = scaler.transform(input_data_array)
    
    predictions = best_model.predict(input_data_array)
    clothing_type_prediction = predictions[0]
    season_prediction = predictions[1]
    
    clothing_type_result = clothing_type_encoder.inverse_transform([np.argmax(clothing_type_prediction)])[0]
    season_result = label_encoders['season'].inverse_transform([np.argmax(season_prediction)])[0]
    
    return clothing_type_result, season_result

# 예측 예시
input_data = {'gender': 'FEMALE', 'age': '20대', 'temperature': 5}
clothing_type_result, season_result = predict(input_data)

outerwear_types = ['01outer_01coat', '01outer_02jacket', '01outer_03parka', '01outer_04anorak', '01outer_05cardigan']

print(f'Predicted Season: {season_result}')
if season_result == 'summer' and clothing_type_result in outerwear_types:
    print(f'Predicted Clothing Type: {clothing_type_result}. 아우터는 추천하지 않습니다.')
else:
    print(f'Predicted Clothing Type: {clothing_type_result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Predicted Season: spring&fall
# Predicted Clothing Type: 01outer_02jacket
